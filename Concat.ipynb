# %%
import pandas as pd

# %%
Jan17=pd.read_csv('data/JC-201701-citibike-tripdata.csv')
Feb17=pd.read_csv('data/JC-201702-citibike-tripdata.csv')
Mar17=pd.read_csv('data/JC-201703-citibike-tripdata.csv')
Apr17=pd.read_csv('data/JC-201704-citibike-tripdata.csv')
May17=pd.read_csv('data/JC-201705-citibike-tripdata.csv')
Jun17=pd.read_csv('data/JC-201706-citibike-tripdata.csv')
Jul17=pd.read_csv('data/JC-201707-citibike-tripdata.csv')
Aug17=pd.read_csv('data/JC-201708-citibike-tripdata.csv')
Sep17=pd.read_csv('data/JC-201709-citibike-tripdata.csv')
Oct17=pd.read_csv('data/JC-201710-citibike-tripdata.csv')
Nov17=pd.read_csv('data/JC-201711-citibike-tripdata.csv')
Dec17=pd.read_csv('data/JC-201712-citibike-tripdata.csv')
Jan18=pd.read_csv('data/JC-201801-citibike-tripdata.csv')
Feb18=pd.read_csv('data/JC-201802-citibike-tripdata.csv')
Mar18=pd.read_csv('data/JC-201803-citibike-tripdata.csv')
Apr18=pd.read_csv('data/JC-201804-citibike-tripdata.csv')
May18=pd.read_csv('data/JC-201805-citibike-tripdata.csv')
Jun18=pd.read_csv('data/JC-201806-citibike-tripdata.csv')
Jul18=pd.read_csv('data/JC-201807-citibike-tripdata.csv')
Aug18=pd.read_csv('data/JC-201808-citibike-tripdata.csv')
Sep18=pd.read_csv('data/JC-201809-citibike-tripdata.csv')
Oct18=pd.read_csv('data/JC-201810-citibike-tripdata.csv')
Nov18=pd.read_csv('data/JC-201811-citibike-tripdata.csv')
Dec18=pd.read_csv('data/JC-201812-citibike-tripdata.csv')
Jan19=pd.read_csv('data/JC-201901-citibike-tripdata.csv')
Feb19=pd.read_csv('data/JC-201902-citibike-tripdata.csv')
Mar19=pd.read_csv('data/JC-201903-citibike-tripdata.csv')
Apr19=pd.read_csv('data/JC-201904-citibike-tripdata.csv')
May19=pd.read_csv('data/JC-201905-citibike-tripdata.csv')
Jun19=pd.read_csv('data/JC-201906-citibike-tripdata.csv')
Jul19=pd.read_csv('data/JC-201907-citibike-tripdata.csv')
Aug19=pd.read_csv('data/JC-201908-citibike-tripdata.csv')
Sep19=pd.read_csv('data/JC-201909-citibike-tripdata.csv')
Oct19=pd.read_csv('data/JC-201910-citibike-tripdata.csv')
Nov19=pd.read_csv('data/JC-201911-citibike-tripdata.csv')
Dec19=pd.read_csv('data/JC-201912-citibike-tripdata.csv')
Jan20=pd.read_csv('data/JC-202001-citibike-tripdata.csv')
Feb20=pd.read_csv('data/JC-202002-citibike-tripdata.csv')
Mar20=pd.read_csv('data/JC-202003-citibike-tripdata.csv')
Apr20=pd.read_csv('data/JC-202004-citibike-tripdata.csv')
May20=pd.read_csv('data/JC-202005-citibike-tripdata.csv')
Jun20=pd.read_csv('data/JC-202006-citibike-tripdata.csv')
Jul20=pd.read_csv('data/JC-202007-citibike-tripdata.csv')
Aug20=pd.read_csv('data/JC-202008-citibike-tripdata.csv')
Sep20=pd.read_csv('data/JC-202009-citibike-tripdata.csv')

# %%
Apr17.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
names = pd.concat([Jan17,Feb17,Mar17])

# %%
names.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
new = names.rename(columns={'Trip Duration':'tripduration', 'Start Time': 'starttime', 'Stop Time':'stoptime', 'Start Station ID':'start station id',
       'Start Station Name':'start station name', 'Start Station Latitude':'start station latitude',
       'Start Station Longitude':'start station longitude', 'End Station ID':'end station id', 'End Station Name':'end station name',
       'End Station Latitude': 'end station latitude', 'End Station Longitude':'end station longitude', 'Bike ID':'bikeid', 'User Type':'usertype',
       'Birth Year':'birth year', 'Gender':'gender'})
# Out:
#        tripduration            starttime             stoptime  \
# 0               148  2017-01-01 00:21:32  2017-01-01 00:24:01
# 1              1283  2017-01-01 00:24:35  2017-01-01 00:45:58
# 2               372  2017-01-01 00:38:19  2017-01-01 00:44:31
# 3              1513  2017-01-01 00:38:37  2017-01-01 01:03:50
# 4               639  2017-01-01 01:47:52  2017-01-01 01:58:31
# ...             ...                  ...                  ...
# 12196           239  2017-03-31 21:26:40  2017-03-31 21:30:39
# 12197           192  2017-03-31 21:46:57  2017-03-31 21:50:09
# 12198           186  2017-03-31 22:03:56  2017-03-31 22:07:02
# 12199           618  2017-03-31 23:20:14  2017-03-31 23:30:32
# 12200           649  2017-03-31 23:25:34  2017-03-31 23:36:23
#
#        start station id start station name  start station latitude  \
# 0                  3276   Marin Light Rail               40.714584
# 1                  3183     Exchange Place               40.716247
# ...

# %%
df = pd.concat([Apr17,May17,Jun17,Jul17,Aug17,Sep17,
                Oct17,Nov17,Dec17,Jan18,Feb18,Mar18,Apr18,May18,Jun18,
                Jul18,Aug18,Sep18,Oct18,Nov18,Dec18,Jan19,Feb19,Mar19,
                Apr19,May19,Jun19,Jul19,Aug19,Sep19,Oct19,Nov19,Dec19,
                Jan20,Feb20,Mar20,Apr20,May20,Jun20,Jul20,Aug20,Sep20])

# %%
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               252       2017-04-01 00:14:36       2017-04-01 00:18:48
# 1               452       2017-04-01 00:15:47       2017-04-01 00:23:20
# 2               465       2017-04-01 00:46:27       2017-04-01 00:54:13
# 3               417       2017-04-01 00:47:15       2017-04-01 00:54:13
# 4               391       2017-04-01 01:13:12       2017-04-01 01:19:44
# ...             ...                       ...                       ...
# 53828           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 53829           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 53830           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 53831           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 53832           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#        start station id   start station name  start station latitude  \
# ...

# %%
final = pd.concat([new,df])

# %%
final

# %%
final.to_csv('data/Jan17_to_Sep20.csv', index=False)
