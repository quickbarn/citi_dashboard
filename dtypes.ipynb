# %%
import pandas as pd

# %%
df=pd.read_csv('data/Jan17_to_Sep20.csv')

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df['birth year'] = pd.to_datetime(df['birth year'], format='%Y')

# %%
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 148       2017-01-01 00:21:32       2017-01-01 00:24:01
# 1                1283       2017-01-01 00:24:35       2017-01-01 00:45:58
# 2                 372       2017-01-01 00:38:19       2017-01-01 00:44:31
# 3                1513       2017-01-01 00:38:37       2017-01-01 01:03:50
# 4                 639       2017-01-01 01:47:52       2017-01-01 01:58:31
# ...               ...                       ...                       ...
# 1327509           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 1327510           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 1327511           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 1327512           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 1327513           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#          start station id start station name  start station latitude  \
# ...

# %%
df.to_csv('data/Final1.0.csv')
